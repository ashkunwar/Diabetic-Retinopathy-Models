# %% [markdown]
# # Import the essentials

# %%
# Imports here
from __future__ import print_function, division
import numpy as np
import matplotlib.pyplot as plt
from torch.utils import data
import torch
from torch import nn
from torch import optim
import torchvision
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision.models as models
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
from skimage import io, transform
import torch.utils.data as data_utils
from PIL import Image, ImageFile
from torch.optim import lr_scheduler
import os
import argparse
import seaborn as sns
import copy
import pandas as pd
ImageFile.LOAD_TRUNCATED_IMAGES = True
import cv2
# Import useful sklearn functions
import sklearn
from sklearn.metrics import cohen_kappa_score, accuracy_score
import time
from tqdm import tqdm_notebook
import seaborn as sns
import warnings

# %% [markdown]
# # Loading Data + EDA

# %%
train_csv = pd.read_csv('/kaggle/input/aptos2019-blindness-detection/train.csv')

test_csv = pd.read_csv('/kaggle/input/aptos2019-blindness-detection/test.csv')

# %%
print('Train Size = {}'.format(len(train_csv)))
print('Public Test Size = {}'.format(len(test_csv)))
# Out:
# Train Size = 3662
# Public Test Size = 1928

# %%
train_csv.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
import matplotlib.pyplot as plt

import seaborn as sns



counts = train_csv['diagnosis'].value_counts()

class_list = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferate']



for i, x in enumerate(class_list):

    counts[x] = counts.pop(i)



plt.figure(figsize=(10, 5))

sns.barplot(x=counts.index, y=counts.values, alpha=0.8, palette='bright')

plt.title('Distribution of Output Classes')

plt.xlabel('Target Classes', fontsize=12)

plt.ylabel('Number of Occurrences', fontsize=12)

plt.show()

# %% [markdown]
# # Visualizing Training Data

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# Define base directory

base_dir = '/kaggle/input/aptos2019-blindness-detection'
# List of image files in the training images folder

train_imgs = os.listdir(os.path.join(base_dir, 'train_images'))



# Plotting images
fig = plt.figure(figsize=(30, 6))
# Display 16 random images
for idx, img in enumerate(np.random.choice(train_imgs, 16)):
    ax = fig.add_subplot(2, 16 // 2, idx + 1, xticks=[], yticks=[])
    im = Image.open(os.path.join(base_dir, "train_images", img))
    plt.imshow(im)
    lab = train_csv.loc[train_csv['id_code'] == img.split('.')[0], 'diagnosis'].values[0]
    ax.set_title('Severity: %s' % lab)

plt.show()

# %% [markdown]
# # Visualizing Test Data

# %%
fig = plt.figure(figsize=(30, 6))

# display 20 images

test_imgs = os.listdir(base_dir+"/test_images")

for idx, img in enumerate(np.random.choice(test_imgs, 16)):

    ax = fig.add_subplot(2, 16//2, idx+1, xticks=[], yticks=[])

    im = Image.open(base_dir+"/test_images/" + img)

    plt.imshow(im)

# %% [markdown]
# # Data Pre Processing

# %%
class CreateDataset(Dataset):

    def __init__(self, df_data, data_dir = '../input/', transform=None):

        super().__init__()

        self.df = df_data.values

        self.data_dir = data_dir

        self.transform = transform



    def __len__(self):

        return len(self.df)



    def __getitem__(self, index):

        img_name,label = self.df[index]

        img_path = os.path.join(self.data_dir, img_name+'.png')

        image = cv2.imread(img_path)

        if self.transform is not None:

            image = self.transform(image)

        return image, label

# %%
train_transforms = transforms.Compose([

    transforms.ToPILImage(),

    transforms.Resize((256, 256)),

    transforms.RandomHorizontalFlip(p=0.4),

    transforms.ToTensor(),

    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))

])

# %%
test_transforms = transforms.Compose([transforms.Resize(256),

                                      transforms.CenterCrop(224),

                                      transforms.ToTensor(),

                                      transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

# %%
train_path = "/kaggle/input/aptos2019-blindness-detection/train_images"

test_path = "/kaggle/input/aptos2019-blindness-detection/test_images"

# %%
train_data = CreateDataset(df_data=train_csv, data_dir=train_path, transform=train_transforms)

test_data = CreateDataset(df_data=test_csv, data_dir=test_path, transform=test_transforms)

# %%
valid_size = 0.2

num_train = len(train_data)

indices = list(range(num_train))

np.random.shuffle(indices)

split = int(np.floor(valid_size * num_train))

train_idx, valid_idx = indices[split:], indices[:split]

# %%
train_sampler = SubsetRandomSampler(train_idx)

valid_sampler = SubsetRandomSampler(valid_idx)

# %%
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64,sampler=train_sampler)

validloader = torch.utils.data.DataLoader(train_data, batch_size=64, sampler=valid_sampler)

testloader = torch.utils.data.DataLoader(test_data, batch_size=64)

# %%
print(f"training examples contain : {len(train_data)}")

print(f"testing examples contain : {len(test_data)}")
# Out:
# training examples contain : 3662
# testing examples contain : 1928

# %%
images, labels = next(iter(trainloader))

# Checking shape of image

print(f"Image shape : {images.shape}")

print(f"Label shape : {labels.shape}")



# denormalizing images for printing as they are in tensors

def imshow(inp, title=None):

    """Imshow for Tensor."""

    inp = inp.numpy().transpose((1, 2, 0))

    mean = np.array([0.485, 0.456, 0.406])

    std = np.array([0.229, 0.224, 0.225])

    inp = std * inp + mean

    inp = np.clip(inp, 0, 1)

    plt.imshow(inp)

    if title is not None:

        plt.title(title)

    plt.pause(0.001)
# Out:
# Image shape : torch.Size([64, 3, 256, 256])
# Label shape : torch.Size([64])

# %%
# plotting the images of loaded batch with given fig size and frame data

import torchvision

import matplotlib.pyplot as plt

import numpy as np

grid = torchvision.utils.make_grid(images, nrow=30, padding=7)

# Move the tensor to CPU before transposing

grid = grid.cpu()

plt.figure(figsize=(20, 20))

plt.imshow(np.transpose(grid, (1, 2, 0)))

print('labels:', labels)
# Out:
# labels: tensor([3, 0, 1, 0, 1, 1, 0, 4, 0, 2, 2, 2, 0, 0, 0, 2, 0, 0, 0, 2, 2, 4, 1, 2,
#         2, 1, 0, 0, 0, 4, 0, 0, 2, 0, 2, 0, 0, 0, 2, 0, 2, 0, 0, 0, 0, 0, 0, 2,
#         0, 2, 2, 3, 2, 0, 0, 0, 0, 0, 0, 4, 0, 2, 0, 0])

# %%
class_names = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferative DR']



images, labels = next(iter(trainloader))

out = torchvision.utils.make_grid(images)

imshow(out, title=[class_names[x] for x in labels])

# %%
###SHUTIL####



import os

import shutil

import random



# Set the directory paths

train = '/kaggle/input/aptos2019-blindness-detection/train_images'

test = '/kaggle/input/aptos2019-blindness-detection/test_images'

# Create the validation directory if it doesn't exist

os.makedirs('test' , exist_ok=True)

os.makedirs('train' , exist_ok=True)

os.makedirs('val' , exist_ok=True)



t_df = pd.read_csv('/kaggle/input/aptos2019-blindness-detection/train.csv')



train_df = t_df.sample(frac = 0.80)

test_df = t_df.drop(train_df.index)

test_df.reset_index(drop=True, inplace=True)



val_df = test_df.sample(frac = 0.45)

test_df = test_df.drop(val_df.index)

test_df.reset_index(drop=True, inplace=True)

val_df.reset_index(drop=True, inplace=True)



train_df.sort_values(by='diagnosis', inplace=True)

train_df.reset_index(drop=True, inplace=True)



test_df.sort_values(by='diagnosis', inplace=True)

test_df.reset_index(drop=True, inplace=True)



val_df.sort_values(by='diagnosis', inplace=True)

val_df.reset_index(drop=True, inplace=True)

# %%
train_df['diagnosis'].value_counts().plot(kind='pie' , labels = list(train_df['diagnosis'].value_counts()))
# Out:
# <Axes: ylabel='count'>

# %%
test_df['diagnosis'].value_counts().plot(kind='pie' , labels = list(test_df['diagnosis'].value_counts()))
# Out:
# <Axes: ylabel='count'>

# %%
val_df['diagnosis'].value_counts().plot(kind='pie' , labels = list(val_df['diagnosis'].value_counts()))
# Out:
# <Axes: ylabel='count'>

# %%
for i in range(5):

  imgs = train_df[train_df['diagnosis'] == i]['id_code'].to_list()

  os.makedirs(os.path.join('train', str(i)), exist_ok=True)

  for j in imgs:

    shutil.copy(os.path.join(train, j+'.png'), os.path.join(f'train/{i}', str(j)+'.png'))

# %%
for i in range(5):

  imgs = test_df[test_df['diagnosis'] == i]['id_code'].to_list()

  os.makedirs(os.path.join('test', str(i)), exist_ok=True)

  for j in imgs:

    shutil.copy(os.path.join(train, j+'.png'), os.path.join(f'test/{i}', str(j)+'.png'))

# %%
for i in range(5):

  imgs = val_df[val_df['diagnosis'] == i]['id_code'].to_list()

  os.makedirs(os.path.join('val', str(i)), exist_ok=True)

  for j in imgs:

    shutil.copy(os.path.join(train, j+'.png'), os.path.join(f'val/{i}', str(j)+'.png'))

# %%
import os
directory_path = "/kaggle/working/test"
# Get the list of directories inside the specified directory
elements = os.listdir(directory_path)
print(f"Number of elements in each directory inside '{directory_path}':")
for element in elements:
    full_path = os.path.join(directory_path, element)
    if os.path.isdir(full_path):  # Check if the element is a directory
        num_elements = len(os.listdir(full_path))
        print(f"Directory: {element}, Number of elements: {num_elements}")
# Out:
# Number of elements in each directory inside '/kaggle/working/test':
# Directory: 2, Number of elements: 106
# Directory: 4, Number of elements: 31
# Directory: 3, Number of elements: 18
# Directory: 1, Number of elements: 39
# Directory: 0, Number of elements: 209

# %%
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, datasets, transforms
from torch.utils.data import DataLoader

# Load the pretrained DenseNet121 model
model = models.densenet121(pretrained=True)

# Modify the fully connected layer to match the number of classes
num_classes = 5
in_features = model.classifier.in_features  # Corrected this line
model.classifier = nn.Sequential(
    nn.Dropout(p=0.35),  # Add Dropout
    nn.Linear(in_features, num_classes)  # Final linear layer for classification
)

# Ensure the last few layers are trainable (fine-tuning)
for param in list(model.features.parameters())[-25:]:
    param.requires_grad = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.00001)

# Define data transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # DenseNet121 standard input size is 224x224
    transforms.RandomHorizontalFlip(p=0.4),
    transforms.RandomVerticalFlip(p=0.4),
    transforms.RandomRotation(degrees=(0, 10)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Prepare datasets and dataloaders
train_dataset = datasets.ImageFolder(root='/kaggle/working/train', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)

val_dataset = datasets.ImageFolder(root='/kaggle/working/val', transform=transform)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# Initialize variable to track best validation accuracy
best_val_accuracy = 0.0
best_model_path = "best_model.pth"  # Path to save the best model

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    start_time = time.time()
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    print(f"Epoch [{epoch + 1}/{num_epochs}] - Training...")

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Calculate accuracy for this batch
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        if (batch_idx + 1) % 10 == 0:  # Print every 10 batches
            train_accuracy = 100 * correct_train / total_train
            print(f"Batch [{batch_idx + 1}/{len(train_loader)}] - "
                  f"Loss: {loss.item():.4f}, "
                  f"Train Accuracy: {train_accuracy:.2f}%")

    # Compute training loss and accuracy for the epoch
    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train

    # Validation loop
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0

    print(f"Epoch [{epoch + 1}/{num_epochs}] - Validating...")

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    # Compute validation loss and accuracy
    val_loss = val_loss / len(val_loader)
    val_accuracy = 100 * correct_val / total_val

    # Check if this is the best model so far and save the weights
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        torch.save(model.state_dict(), best_model_path)
        print(f"Best model saved with validation accuracy: {best_val_accuracy:.2f}%")

    # Print Epoch Summary
    print(f"Epoch [{epoch + 1}/{num_epochs}] - "
          f"Train Loss: {train_loss:.4f}, "
          f"Train Accuracy: {train_accuracy:.2f}%, "
          f"Val Loss: {val_loss:.4f}, "
          f"Val Accuracy: {val_accuracy:.2f}%, "
          f"Time: {time.time() - start_time:.2f} seconds\n")

print("Training complete. Best model saved at:", best_model_path)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 62.4MB/s]
# Epoch [1/10] - Training...
# Batch [10/184] - Loss: 1.3805, Train Accuracy: 43.75%
# Batch [20/184] - Loss: 1.4799, Train Accuracy: 47.81%
# Batch [30/184] - Loss: 1.2089, Train Accuracy: 50.83%
# Batch [40/184] - Loss: 1.0512, Train Accuracy: 53.75%
# Batch [50/184] - Loss: 1.1286, Train Accuracy: 56.38%
# Batch [60/184] - Loss: 0.9098, Train Accuracy: 57.60%
# Batch [70/184] - Loss: 1.1993, Train Accuracy: 58.93%
# Batch [80/184] - Loss: 0.7100, Train Accuracy: 60.47%
# Batch [90/184] - Loss: 0.7834, Train Accuracy: 61.46%
# Batch [100/184] - Loss: 1.0878, Train Accuracy: 62.06%
# Batch [110/184] - Loss: 1.1728, Train Accuracy: 62.56%
# Batch [120/184] - Loss: 1.1067, Train Accuracy: 62.66%
# Batch [130/184] - Loss: 0.6166, Train Accuracy: 63.70%
# Batch [140/184] - Loss: 1.1484, Train Accuracy: 64.11%
# Batch [150/184] - Loss: 0.7991, Train Accuracy: 64.46%
# Batch [160/184] - Loss: 1.1408, Train Accuracy: 64.69%
# Batch [170/184] - Loss: 0.9562, Train Accuracy: 65.07%
# Batch [180/184] - Loss: 0.6677, Train Accuracy: 65.52%
# Epoch [1/10] - Validating...
# Best model saved with validation accuracy: 71.73%
# Epoch [1/10] - Train Loss: 1.0401, Train Accuracy: 65.53%, Val Loss: 0.8385, Val Accuracy: 71.73%, Time: 432.52 seconds
#
# Epoch [2/10] - Training...
# Batch [10/184] - Loss: 0.6840, Train Accuracy: 68.12%
# Batch [20/184] - Loss: 0.9573, Train Accuracy: 71.56%
# Batch [30/184] - Loss: 0.8264, Train Accuracy: 70.21%
# Batch [40/184] - Loss: 0.7419, Train Accuracy: 71.09%
# Batch [50/184] - Loss: 0.7640, Train Accuracy: 72.50%
# Batch [60/184] - Loss: 0.7880, Train Accuracy: 73.02%
# Batch [70/184] - Loss: 1.0033, Train Accuracy: 72.05%
# Batch [80/184] - Loss: 0.9201, Train Accuracy: 71.88%
# Batch [90/184] - Loss: 1.0862, Train Accuracy: 71.88%
# Batch [100/184] - Loss: 0.7604, Train Accuracy: 71.00%
# Batch [110/184] - Loss: 0.6433, Train Accuracy: 71.48%
# Batch [120/184] - Loss: 0.7025, Train Accuracy: 71.82%
# Batch [130/184] - Loss: 1.3744, Train Accuracy: 71.92%
# Batch [140/184] - Loss: 0.7453, Train Accuracy: 71.74%
# Batch [150/184] - Loss: 0.8916, Train Accuracy: 71.88%
# Batch [160/184] - Loss: 0.8507, Train Accuracy: 71.91%
# Batch [170/184] - Loss: 0.7686, Train Accuracy: 72.10%
# Batch [180/184] - Loss: 0.8721, Train Accuracy: 71.84%
# Epoch [2/10] - Validating...
# Best model saved with validation accuracy: 72.64%
# Epoch [2/10] - Train Loss: 0.7872, Train Accuracy: 71.88%, Val Loss: 0.7107, Val Accuracy: 72.64%, Time: 421.35 seconds
#
# Epoch [3/10] - Training...
# Batch [10/184] - Loss: 0.4778, Train Accuracy: 79.38%
# Batch [20/184] - Loss: 0.6044, Train Accuracy: 77.50%
# Batch [30/184] - Loss: 0.6699, Train Accuracy: 78.12%
# Batch [40/184] - Loss: 0.6686, Train Accuracy: 77.50%
# Batch [50/184] - Loss: 0.5549, Train Accuracy: 76.00%
# Batch [60/184] - Loss: 0.6785, Train Accuracy: 77.40%
# Batch [70/184] - Loss: 0.6154, Train Accuracy: 76.61%
# Batch [80/184] - Loss: 0.9105, Train Accuracy: 76.25%
# Batch [90/184] - Loss: 0.8702, Train Accuracy: 75.76%
# Batch [100/184] - Loss: 0.7315, Train Accuracy: 75.69%
# Batch [110/184] - Loss: 0.4257, Train Accuracy: 75.28%
# Batch [120/184] - Loss: 1.0463, Train Accuracy: 75.21%
# Batch [130/184] - Loss: 0.8178, Train Accuracy: 75.00%
# Batch [140/184] - Loss: 0.8092, Train Accuracy: 75.22%
# Batch [150/184] - Loss: 0.8771, Train Accuracy: 75.75%
# Batch [160/184] - Loss: 0.4196, Train Accuracy: 75.66%
# Batch [170/184] - Loss: 0.5004, Train Accuracy: 75.51%
# Batch [180/184] - Loss: 0.4242, Train Accuracy: 75.73%
# Epoch [3/10] - Validating...
# Best model saved with validation accuracy: 75.08%
# Epoch [3/10] - Train Loss: 0.6839, Train Accuracy: 75.73%, Val Loss: 0.6596, Val Accuracy: 75.08%, Time: 415.31 seconds
#
# Epoch [4/10] - Training...
# Batch [10/184] - Loss: 0.7195, Train Accuracy: 80.00%
# Batch [20/184] - Loss: 0.7095, Train Accuracy: 80.31%
# Batch [30/184] - Loss: 0.6603, Train Accuracy: 78.96%
# Batch [40/184] - Loss: 0.5599, Train Accuracy: 77.50%
# Batch [50/184] - Loss: 0.3986, Train Accuracy: 77.62%
# Batch [60/184] - Loss: 0.4720, Train Accuracy: 77.50%
# Batch [70/184] - Loss: 0.6233, Train Accuracy: 77.05%
# Batch [80/184] - Loss: 0.7402, Train Accuracy: 77.73%
# Batch [90/184] - Loss: 1.0953, Train Accuracy: 78.68%
# Batch [100/184] - Loss: 0.3799, Train Accuracy: 78.62%
# Batch [110/184] - Loss: 0.5071, Train Accuracy: 79.03%
# Batch [120/184] - Loss: 0.6105, Train Accuracy: 79.01%
# Batch [130/184] - Loss: 0.4734, Train Accuracy: 78.99%
# Batch [140/184] - Loss: 1.1982, Train Accuracy: 78.53%
# Batch [150/184] - Loss: 0.9732, Train Accuracy: 78.42%
# Batch [160/184] - Loss: 1.0435, Train Accuracy: 78.24%
# Batch [170/184] - Loss: 0.5426, Train Accuracy: 77.90%
# Batch [180/184] - Loss: 0.9610, Train Accuracy: 77.64%
# Epoch [4/10] - Validating...
# Best model saved with validation accuracy: 78.72%
# Epoch [4/10] - Train Loss: 0.6108, Train Accuracy: 77.75%, Val Loss: 0.6099, Val Accuracy: 78.72%, Time: 414.31 seconds
#
# Epoch [5/10] - Training...
# Batch [10/184] - Loss: 0.8077, Train Accuracy: 75.00%
# Batch [20/184] - Loss: 0.4567, Train Accuracy: 76.56%
# Batch [30/184] - Loss: 0.3946, Train Accuracy: 77.50%
# Batch [40/184] - Loss: 0.9193, Train Accuracy: 76.25%
# Batch [50/184] - Loss: 0.4988, Train Accuracy: 74.75%
# Batch [60/184] - Loss: 0.5262, Train Accuracy: 76.15%
# Batch [70/184] - Loss: 0.5036, Train Accuracy: 76.96%
# Batch [80/184] - Loss: 0.5452, Train Accuracy: 77.66%
# Batch [90/184] - Loss: 0.3998, Train Accuracy: 78.40%
# Batch [100/184] - Loss: 0.7517, Train Accuracy: 78.62%
# Batch [110/184] - Loss: 0.3822, Train Accuracy: 78.92%
# Batch [120/184] - Loss: 0.8098, Train Accuracy: 78.96%
# Batch [130/184] - Loss: 0.7314, Train Accuracy: 78.99%
# Batch [140/184] - Loss: 0.3810, Train Accuracy: 79.06%
# Batch [150/184] - Loss: 0.9470, Train Accuracy: 79.04%
# Batch [160/184] - Loss: 0.5274, Train Accuracy: 79.18%
# Batch [170/184] - Loss: 0.6917, Train Accuracy: 79.34%
# Batch [180/184] - Loss: 0.5873, Train Accuracy: 79.51%
# Epoch [5/10] - Validating...
# Best model saved with validation accuracy: 79.64%
# Epoch [5/10] - Train Loss: 0.5808, Train Accuracy: 79.59%, Val Loss: 0.5626, Val Accuracy: 79.64%, Time: 415.21 seconds
#
# Epoch [6/10] - Training...
# Batch [10/184] - Loss: 0.4046, Train Accuracy: 80.62%
# Batch [20/184] - Loss: 0.5163, Train Accuracy: 77.19%
# Batch [30/184] - Loss: 0.4255, Train Accuracy: 78.54%
# Batch [40/184] - Loss: 0.5977, Train Accuracy: 78.44%
# Batch [50/184] - Loss: 0.6869, Train Accuracy: 78.88%
# Batch [60/184] - Loss: 0.7590, Train Accuracy: 78.85%
# Batch [70/184] - Loss: 0.4959, Train Accuracy: 78.75%
# Batch [80/184] - Loss: 0.8076, Train Accuracy: 79.61%
# Batch [90/184] - Loss: 0.4854, Train Accuracy: 79.44%
# Batch [100/184] - Loss: 0.8151, Train Accuracy: 80.00%
# Batch [110/184] - Loss: 0.4730, Train Accuracy: 80.00%
# Batch [120/184] - Loss: 0.8286, Train Accuracy: 80.47%
# Batch [130/184] - Loss: 0.6325, Train Accuracy: 79.81%
# Batch [140/184] - Loss: 0.4439, Train Accuracy: 79.55%
# Batch [150/184] - Loss: 0.4044, Train Accuracy: 79.38%
# Batch [160/184] - Loss: 0.5313, Train Accuracy: 79.53%
# Batch [170/184] - Loss: 0.6988, Train Accuracy: 79.26%
# Batch [180/184] - Loss: 0.5886, Train Accuracy: 79.24%
# Epoch [6/10] - Validating...
# Best model saved with validation accuracy: 80.24%
# Epoch [6/10] - Train Loss: 0.5559, Train Accuracy: 79.35%, Val Loss: 0.5657, Val Accuracy: 80.24%, Time: 415.05 seconds
#
# Epoch [7/10] - Training...
# Batch [10/184] - Loss: 0.3515, Train Accuracy: 83.75%
# Batch [20/184] - Loss: 0.3937, Train Accuracy: 83.44%
# Batch [30/184] - Loss: 0.9075, Train Accuracy: 81.88%
# Batch [40/184] - Loss: 0.3144, Train Accuracy: 82.34%
# Batch [50/184] - Loss: 0.3297, Train Accuracy: 81.88%
# Batch [60/184] - Loss: 0.5388, Train Accuracy: 82.50%
# Batch [70/184] - Loss: 0.3752, Train Accuracy: 81.61%
# Batch [80/184] - Loss: 0.6388, Train Accuracy: 81.80%
# Batch [90/184] - Loss: 0.6452, Train Accuracy: 81.74%
# Batch [100/184] - Loss: 0.6411, Train Accuracy: 81.38%
# Batch [110/184] - Loss: 0.3657, Train Accuracy: 81.36%
# Batch [120/184] - Loss: 0.3513, Train Accuracy: 81.88%
# Batch [130/184] - Loss: 0.4787, Train Accuracy: 81.83%
# Batch [140/184] - Loss: 0.6008, Train Accuracy: 81.47%
# Batch [150/184] - Loss: 0.5184, Train Accuracy: 81.62%
# Batch [160/184] - Loss: 0.4595, Train Accuracy: 81.25%
# Batch [170/184] - Loss: 0.4826, Train Accuracy: 81.14%
# Batch [180/184] - Loss: 0.4736, Train Accuracy: 81.11%
# Epoch [7/10] - Validating...
# Epoch [7/10] - Train Loss: 0.5099, Train Accuracy: 81.13%, Val Loss: 0.5403, Val Accuracy: 79.64%, Time: 415.14 seconds
#
# Epoch [8/10] - Training...
# Batch [10/184] - Loss: 0.4493, Train Accuracy: 84.38%
# Batch [20/184] - Loss: 0.4218, Train Accuracy: 84.38%
# Batch [30/184] - Loss: 0.4698, Train Accuracy: 83.54%
# Batch [40/184] - Loss: 0.6509, Train Accuracy: 82.03%
# Batch [50/184] - Loss: 0.3892, Train Accuracy: 82.25%
# Batch [60/184] - Loss: 0.6159, Train Accuracy: 82.19%
# Batch [70/184] - Loss: 0.4943, Train Accuracy: 82.32%
# Batch [80/184] - Loss: 0.3185, Train Accuracy: 82.19%
# Batch [90/184] - Loss: 0.4119, Train Accuracy: 82.22%
# Batch [100/184] - Loss: 0.3829, Train Accuracy: 82.25%
# Batch [110/184] - Loss: 0.6976, Train Accuracy: 82.27%
# Batch [120/184] - Loss: 0.5267, Train Accuracy: 82.55%
# Batch [130/184] - Loss: 0.3434, Train Accuracy: 82.84%
# Batch [140/184] - Loss: 0.4571, Train Accuracy: 82.77%
# Batch [150/184] - Loss: 0.5172, Train Accuracy: 82.58%
# Batch [160/184] - Loss: 0.3574, Train Accuracy: 82.27%
# Batch [170/184] - Loss: 0.4591, Train Accuracy: 82.17%
# Batch [180/184] - Loss: 0.4671, Train Accuracy: 81.91%
# Epoch [8/10] - Validating...
# Best model saved with validation accuracy: 81.16%
# Epoch [8/10] - Train Loss: 0.4948, Train Accuracy: 81.81%, Val Loss: 0.5293, Val Accuracy: 81.16%, Time: 414.44 seconds
#
# Epoch [9/10] - Training...
# Batch [10/184] - Loss: 0.6260, Train Accuracy: 83.75%
# Batch [20/184] - Loss: 0.5735, Train Accuracy: 82.19%
# Batch [30/184] - Loss: 0.3819, Train Accuracy: 83.33%
# Batch [40/184] - Loss: 0.4137, Train Accuracy: 83.28%
# Batch [50/184] - Loss: 0.4713, Train Accuracy: 83.75%
# Batch [60/184] - Loss: 0.3369, Train Accuracy: 82.92%
# Batch [70/184] - Loss: 0.4411, Train Accuracy: 83.39%
# Batch [80/184] - Loss: 0.2287, Train Accuracy: 83.59%
# Batch [90/184] - Loss: 0.5189, Train Accuracy: 83.68%
# Batch [100/184] - Loss: 0.5796, Train Accuracy: 82.94%
# Batch [110/184] - Loss: 0.3555, Train Accuracy: 83.01%
# Batch [120/184] - Loss: 0.9311, Train Accuracy: 83.28%
# Batch [130/184] - Loss: 0.3914, Train Accuracy: 83.41%
# Batch [140/184] - Loss: 0.4676, Train Accuracy: 83.53%
# Batch [150/184] - Loss: 0.7642, Train Accuracy: 82.96%
# Batch [160/184] - Loss: 0.5705, Train Accuracy: 82.85%
# Batch [170/184] - Loss: 0.4073, Train Accuracy: 82.54%
# Batch [180/184] - Loss: 0.3871, Train Accuracy: 82.43%
# Epoch [9/10] - Validating...
# Best model saved with validation accuracy: 82.37%
# Epoch [9/10] - Train Loss: 0.4790, Train Accuracy: 82.39%, Val Loss: 0.5160, Val Accuracy: 82.37%, Time: 415.70 seconds
#
# Epoch [10/10] - Training...
# Batch [10/184] - Loss: 0.2993, Train Accuracy: 78.12%
# Batch [20/184] - Loss: 0.5958, Train Accuracy: 78.12%
# Batch [30/184] - Loss: 0.3079, Train Accuracy: 81.88%
# Batch [40/184] - Loss: 0.6208, Train Accuracy: 81.72%
# Batch [50/184] - Loss: 0.2809, Train Accuracy: 82.12%
# Batch [60/184] - Loss: 0.3427, Train Accuracy: 81.98%
# Batch [70/184] - Loss: 0.4365, Train Accuracy: 81.61%
# Batch [80/184] - Loss: 0.5225, Train Accuracy: 82.19%
# Batch [90/184] - Loss: 0.5465, Train Accuracy: 82.57%
# Batch [100/184] - Loss: 0.7761, Train Accuracy: 82.75%
# Batch [110/184] - Loss: 0.3590, Train Accuracy: 82.90%
# Batch [120/184] - Loss: 0.2778, Train Accuracy: 82.81%
# Batch [130/184] - Loss: 0.4082, Train Accuracy: 82.88%
# Batch [140/184] - Loss: 0.4258, Train Accuracy: 83.08%
# Batch [150/184] - Loss: 0.2602, Train Accuracy: 83.46%
# Batch [160/184] - Loss: 0.2828, Train Accuracy: 83.55%
# Batch [170/184] - Loss: 0.1744, Train Accuracy: 83.75%
# Batch [180/184] - Loss: 0.4166, Train Accuracy: 83.47%
# Epoch [10/10] - Validating...
# Best model saved with validation accuracy: 82.98%
# Epoch [10/10] - Train Loss: 0.4576, Train Accuracy: 83.48%, Val Loss: 0.4961, Val Accuracy: 82.98%, Time: 416.09 seconds
#
# Training complete. Best model saved at: best_model.pth

# %%
# Save the entire model
torch.save(model, 'model.pth')

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import models, datasets, transforms
from sklearn.metrics import precision_score, recall_score, f1_score, cohen_kappa_score

# Load the pretrained DenseNet-121 model
model = models.densenet121(pretrained=True)
num_classes = 5

# Modify the final classifier layer to match the number of classes
model.classifier = nn.Sequential(
    nn.Dropout(p=0.35),  # Match this with the saved model's architecture
    nn.Linear(in_features, num_classes)
)


# Load the fine-tuned model weights
model.load_state_dict(torch.load('best_model.pth'))
model.eval()

# Define the data transformation
transform = transforms.Compose([
    transforms.Resize((224, 224)),  
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the test dataset
test_dir = '/kaggle/working/test'
test_dataset = datasets.ImageFolder(root=test_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# Evaluation function
def evaluate(model, test_loader, criterion, device):
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item() * images.size(0)

            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = test_loss / total
    accuracy = correct / total

    return avg_loss, accuracy, all_preds, all_labels

# Set up device and loss function
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
criterion = nn.CrossEntropyLoss()

# Evaluate the model
test_loss, test_accuracy, all_preds, all_labels = evaluate(model, test_loader, criterion, device)

# Print test results
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy * 100:.2f}%")

# Calculate evaluation metrics
precision = precision_score(all_labels, all_preds, average='weighted')
recall = recall_score(all_labels, all_preds, average='weighted')
f1 = f1_score(all_labels, all_preds, average='weighted')
kappa_score = cohen_kappa_score(all_labels, all_preds)
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Cohen's Kappa Score: {kappa_score:.4f}")
# Out:
# /tmp/ipykernel_30/3759808324.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model.pth'))
# Test Loss: 0.4568, Test Accuracy: 83.13%
# Precision: 0.8234
# Recall: 0.8313
# F1 Score: 0.8171
# Cohen's Kappa Score: 0.7314

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
cm = confusion_matrix(all_labels, all_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
