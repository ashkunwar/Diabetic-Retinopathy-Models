# %% [markdown]
# # Import the essentials

# %%
# Imports here
from __future__ import print_function, division
import numpy as np
import matplotlib.pyplot as plt
from torch.utils import data
import torch
from torch import nn
from torch import optim
import torchvision
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision.models as models
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
from skimage import io, transform
import torch.utils.data as data_utils
from PIL import Image, ImageFile
import json
from torch.optim import lr_scheduler
import time
import os
import argparse
import copy
import pandas as pd
ImageFile.LOAD_TRUNCATED_IMAGES = True
import cv2
# Import useful sklearn functions
import sklearn
from sklearn.metrics import cohen_kappa_score, accuracy_score
import time
from tqdm import tqdm_notebook

# %%
import seaborn as sns

# %%
# !kaggle competitions download -c aptos2019-blindness-detection

# %%
# Unzip the downloaded files
# !unzip aptos2019-blindness-detection.zip -d aptos2019

# %% [markdown]
# # Loading Data + EDA

# %%
train_csv = pd.read_csv('/content/aptos2019/train.csv')
test_csv = pd.read_csv('/content/aptos2019/test.csv')

# %%
print('Train Size = {}'.format(len(train_csv)))
print('Public Test Size = {}'.format(len(test_csv)))
# Out:
# Train Size = 3662
# Public Test Size = 1928

# %%
train_csv.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

counts = train_csv['diagnosis'].value_counts()
class_list = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferate']

for i, x in enumerate(class_list):
    counts[x] = counts.pop(i)

plt.figure(figsize=(10, 5))
sns.barplot(x=counts.index, y=counts.values, alpha=0.8, palette='bright')
plt.title('Distribution of Output Classes')
plt.xlabel('Target Classes', fontsize=12)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.show()
# Out:
# <ipython-input-9-9e6b09e95b41>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, alpha=0.8, palette='bright')

# %% [markdown]
# # Visualizing Training Data

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Define base directory
base_dir = '/content/aptos2019'

# List of image files in the training images folder
train_imgs = os.listdir(os.path.join(base_dir, 'train_images'))

# Plotting images
fig = plt.figure(figsize=(30, 6))
# Display 16 random images
for idx, img in enumerate(np.random.choice(train_imgs, 16)):
    ax = fig.add_subplot(2, 16 // 2, idx + 1, xticks=[], yticks=[])
    im = Image.open(os.path.join(base_dir, "train_images", img))
    plt.imshow(im)
    lab = train_csv.loc[train_csv['id_code'] == img.split('.')[0], 'diagnosis'].values[0]
    ax.set_title('Severity: %s' % lab)

plt.show()

# %% [markdown]
# # Visualizing Test Set

# %%
fig = plt.figure(figsize=(30, 6))
# display 20 images
test_imgs = os.listdir(base_dir+"/test_images")
for idx, img in enumerate(np.random.choice(test_imgs, 16)):
    ax = fig.add_subplot(2, 16//2, idx+1, xticks=[], yticks=[])
    im = Image.open(base_dir+"/test_images/" + img)
    plt.imshow(im)

# %% [markdown]
# # Data Processing

# %%
class CreateDataset(Dataset):
    def __init__(self, df_data, data_dir = '../input/', transform=None):
        super().__init__()
        self.df = df_data.values
        self.data_dir = data_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        img_name,label = self.df[index]
        img_path = os.path.join(self.data_dir, img_name+'.png')
        image = cv2.imread(img_path)
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
train_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(p=0.4),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])

# %%
test_transforms = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

# %%
train_path = "/content/aptos2019/train_images"
test_path = "/content/aptos2019/test.csv"

# %%
train_data = CreateDataset(df_data=train_csv, data_dir=train_path, transform=train_transforms)
test_data = CreateDataset(df_data=test_csv, data_dir=test_path, transform=test_transforms)

# %%
valid_size = 0.2
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# %%
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64,sampler=train_sampler)
validloader = torch.utils.data.DataLoader(train_data, batch_size=64, sampler=valid_sampler)
testloader = torch.utils.data.DataLoader(test_data, batch_size=64)

# %%
print(f"training examples contain : {len(train_data)}")
print(f"testing examples contain : {len(test_data)}")
# Out:
# training examples contain : 3662
# testing examples contain : 1928

# %%
images, labels = next(iter(trainloader))

# Checking shape of image
print(f"Image shape : {images.shape}")
print(f"Label shape : {labels.shape}")

# denormalizing images for printing as they are in tensors
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)
# Out:
# Image shape : torch.Size([64, 3, 224, 224])
# Label shape : torch.Size([64])

# %%
# plotting the images of loaded batch with given fig size and frame data
import torchvision
import matplotlib.pyplot as plt
import numpy as np
grid = torchvision.utils.make_grid(images, nrow=30, padding=7)
# Move the tensor to CPU before transposing
grid = grid.cpu()
plt.figure(figsize=(20, 20))
plt.imshow(np.transpose(grid, (1, 2, 0)))
print('labels:', labels)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# labels: tensor([1, 0, 0, 0, 0, 1, 4, 0, 0, 1, 1, 0, 0, 0, 0, 2, 2, 0, 0, 0, 2, 4, 1, 2,
#         1, 0, 0, 0, 4, 0, 0, 2, 4, 2, 4, 4, 2, 0, 2, 2, 2, 0, 0, 0, 2, 0, 0, 3,
#         0, 2, 4, 0, 3, 1, 0, 0, 2, 2, 4, 0, 0, 2, 4, 4])

# %%
class_names = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferative DR']

images, labels = next(iter(trainloader))
out = torchvision.utils.make_grid(images)
imshow(out, title=[class_names[x] for x in labels])

# %%
###SHUTIL####

import os
import shutil
import random

# Set the directory paths
train = '/content/aptos2019/train_images'
test = '/content/aptos2019/test_images'
# Create the validation directory if it doesn't exist
os.makedirs('test' , exist_ok=True)
os.makedirs('train' , exist_ok=True)
os.makedirs('val' , exist_ok=True)

t_df = pd.read_csv('/content/aptos2019/train.csv')

train_df = t_df.sample(frac = 0.80)
test_df = t_df.drop(train_df.index)
test_df.reset_index(drop=True, inplace=True)

val_df = test_df.sample(frac = 0.45)
test_df = test_df.drop(val_df.index)
test_df.reset_index(drop=True, inplace=True)
val_df.reset_index(drop=True, inplace=True)

train_df.sort_values(by='diagnosis', inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df.sort_values(by='diagnosis', inplace=True)
test_df.reset_index(drop=True, inplace=True)

val_df.sort_values(by='diagnosis', inplace=True)
val_df.reset_index(drop=True, inplace=True)

# %%
train_df['diagnosis'].value_counts().plot(kind='pie' , labels = list(train_df['diagnosis'].value_counts()))
# Out:
# <Axes: ylabel='count'>

# %%
test_df['diagnosis'].value_counts().plot(kind='pie' , labels = list(test_df['diagnosis'].value_counts()))
# Out:
# <Axes: ylabel='count'>

# %%
val_df['diagnosis'].value_counts().plot(kind='pie' , labels = list(val_df['diagnosis'].value_counts()))
# Out:
# <Axes: ylabel='count'>

# %%
for i in range(5):
  imgs = train_df[train_df['diagnosis'] == i]['id_code'].to_list()
  os.makedirs(os.path.join('train', str(i)), exist_ok=True)
  for j in imgs:
    shutil.copy(os.path.join(train, j+'.png'), os.path.join(f'train/{i}', str(j)+'.png'))

# %%
for i in range(5):
  imgs = test_df[test_df['diagnosis'] == i]['id_code'].to_list()
  os.makedirs(os.path.join('test', str(i)), exist_ok=True)
  for j in imgs:
    shutil.copy(os.path.join(train, j+'.png'), os.path.join(f'test/{i}', str(j)+'.png'))

# %%
for i in range(5):
  imgs = val_df[val_df['diagnosis'] == i]['id_code'].to_list()
  os.makedirs(os.path.join('val', str(i)), exist_ok=True)
  for j in imgs:
    shutil.copy(os.path.join(train, j+'.png'), os.path.join(f'val/{i}', str(j)+'.png'))

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# !pip install pretrainedmodels

# %%
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, datasets, transforms
from torch.utils.data import DataLoader
from pretrainedmodels import resnet50

# Load the pretrained resnet50 model
model = resnet50(num_classes=1000, pretrained='imagenet')

# Unfreeze only the last 10 layers(finetuning)
layers = list(model.children())
for layer in layers[:-10]:
    for param in layer.parameters():
        param.requires_grad = False

num_classes = 5
in_features = model.last_linear.in_features
model.last_linear = nn.Linear(in_features, num_classes)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.00001)
transform = transforms.Compose([
    transforms.Resize((299, 299)),
    transforms.RandomHorizontalFlip(p=0.4),
    transforms.RandomVerticalFlip(p=0.4),
    transforms.RandomRotation(degrees=(0, 10)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

train_dataset = datasets.ImageFolder(root='/content/train', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_dataset = datasets.ImageFolder(root='/content/val', transform=transform)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Initialize variable to track best validation accuracy
best_val_accuracy = 0.0
best_model_path = "best_model.pth"  # Path to save the best model

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    start_time = time.time()
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    print(f"Epoch [{epoch + 1}/{num_epochs}] - Training...")

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Calculate accuracy for this batch
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        if (batch_idx + 1) % 10 == 0:  # Print every 10 batches
            train_accuracy = 100 * correct_train / total_train
            print(f"Batch [{batch_idx + 1}/{len(train_loader)}] - "
                  f"Loss: {loss.item():.4f}, "
                  f"Train Accuracy: {train_accuracy:.2f}%")

    # Compute training loss and accuracy for the epoch
    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train

    # Validation loop
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0

    print(f"Epoch [{epoch + 1}/{num_epochs}] - Validating...")
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    # Compute validation loss and accuracy
    val_loss = val_loss / len(val_loader)
    val_accuracy = 100 * correct_val / total_val

    # Check if this is the best model so far and save the weights
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        torch.save(model.state_dict(), best_model_path)
        print(f"Best model saved with validation accuracy: {best_val_accuracy:.2f}%")

    # Print Epoch Summary
    print(f"Epoch [{epoch + 1}/{num_epochs}] - "
          f"Train Loss: {train_loss:.4f}, "
          f"Train Accuracy: {train_accuracy:.2f}%, "
          f"Val Loss: {val_loss:.4f}, "
          f"Val Accuracy: {val_accuracy:.2f}%, "
          f"Time: {time.time() - start_time:.2f} seconds\n")

print("Training complete. Best model saved at:", best_model_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 301MB/s]
# Epoch [1/10] - Training...
# Batch [10/92] - Loss: 1.4170, Train Accuracy: 39.69%
# Batch [20/92] - Loss: 1.1449, Train Accuracy: 44.84%
# Batch [30/92] - Loss: 1.0244, Train Accuracy: 52.50%
# Batch [40/92] - Loss: 0.8632, Train Accuracy: 55.62%
# Batch [50/92] - Loss: 0.9958, Train Accuracy: 59.19%
# Batch [60/92] - Loss: 1.0114, Train Accuracy: 61.72%
# Batch [70/92] - Loss: 0.8291, Train Accuracy: 62.54%
# Batch [80/92] - Loss: 0.7649, Train Accuracy: 64.26%
# Batch [90/92] - Loss: 0.5486, Train Accuracy: 65.59%
# Epoch [1/10] - Validating...
# Best model saved with validation accuracy: 74.16%
# Epoch [1/10] - Train Loss: 0.9928, Train Accuracy: 65.80%, Val Loss: 0.8012, Val Accuracy: 74.16%, Time: 485.18 seconds
#
# Epoch [2/10] - Training...
# Batch [10/92] - Loss: 0.7677, Train Accuracy: 71.56%
# Batch [20/92] - Loss: 0.7980, Train Accuracy: 72.81%
# Batch [30/92] - Loss: 0.7726, Train Accuracy: 74.69%
# Batch [40/92] - Loss: 0.5943, Train Accuracy: 75.86%
# Batch [50/92] - Loss: 0.5437, Train Accuracy: 76.25%
# Batch [60/92] - Loss: 0.4162, Train Accuracy: 76.09%
# Batch [70/92] - Loss: 0.6074, Train Accuracy: 76.25%
# Batch [80/92] - Loss: 0.5433, Train Accuracy: 76.56%
# Batch [90/92] - Loss: 0.6122, Train Accuracy: 76.28%
# Epoch [2/10] - Validating...
# Best model saved with validation accuracy: 76.90%
# Epoch [2/10] - Train Loss: 0.6284, Train Accuracy: 76.48%, Val Loss: 0.6588, Val Accuracy: 76.90%, Time: 467.32 seconds
#
# Epoch [3/10] - Training...
# Batch [10/92] - Loss: 0.7220, Train Accuracy: 78.12%
# Batch [20/92] - Loss: 0.5626, Train Accuracy: 80.16%
# Batch [30/92] - Loss: 0.4324, Train Accuracy: 79.38%
# Batch [40/92] - Loss: 0.5180, Train Accuracy: 80.08%
# Batch [50/92] - Loss: 0.5657, Train Accuracy: 80.31%
# Batch [60/92] - Loss: 0.4548, Train Accuracy: 80.00%
# Batch [70/92] - Loss: 0.5323, Train Accuracy: 79.69%
# Batch [80/92] - Loss: 0.5218, Train Accuracy: 80.04%
# Batch [90/92] - Loss: 0.6617, Train Accuracy: 80.17%
# Epoch [3/10] - Validating...
# Best model saved with validation accuracy: 80.85%
# Epoch [3/10] - Train Loss: 0.5370, Train Accuracy: 80.17%, Val Loss: 0.5644, Val Accuracy: 80.85%, Time: 469.48 seconds
#
# Epoch [4/10] - Training...
# Batch [10/92] - Loss: 0.6948, Train Accuracy: 80.00%
# Batch [20/92] - Loss: 0.3464, Train Accuracy: 81.72%
# Batch [30/92] - Loss: 0.4404, Train Accuracy: 82.40%
# Batch [40/92] - Loss: 0.6386, Train Accuracy: 82.11%
# Batch [50/92] - Loss: 0.3869, Train Accuracy: 82.75%
# Batch [60/92] - Loss: 0.6966, Train Accuracy: 82.29%
# Batch [70/92] - Loss: 0.4012, Train Accuracy: 81.79%
# Batch [80/92] - Loss: 0.6597, Train Accuracy: 81.84%
# Batch [90/92] - Loss: 0.3868, Train Accuracy: 81.94%
# Epoch [4/10] - Validating...
# Best model saved with validation accuracy: 82.37%
# Epoch [4/10] - Train Loss: 0.4729, Train Accuracy: 81.98%, Val Loss: 0.5521, Val Accuracy: 82.37%, Time: 467.25 seconds
#
# Epoch [5/10] - Training...
# Batch [10/92] - Loss: 0.4221, Train Accuracy: 86.88%
# Batch [20/92] - Loss: 0.3492, Train Accuracy: 84.84%
# Batch [30/92] - Loss: 0.4233, Train Accuracy: 84.90%
# Batch [40/92] - Loss: 1.0993, Train Accuracy: 84.14%
# Batch [50/92] - Loss: 0.6326, Train Accuracy: 83.94%
# Batch [60/92] - Loss: 0.3296, Train Accuracy: 83.39%
# Batch [70/92] - Loss: 0.3694, Train Accuracy: 83.62%
# Batch [80/92] - Loss: 0.2233, Train Accuracy: 83.55%
# Batch [90/92] - Loss: 0.5302, Train Accuracy: 83.82%
# Epoch [5/10] - Validating...
# Best model saved with validation accuracy: 82.67%
# Epoch [5/10] - Train Loss: 0.4225, Train Accuracy: 83.92%, Val Loss: 0.5346, Val Accuracy: 82.67%, Time: 463.67 seconds
#
# Epoch [6/10] - Training...
# Batch [10/92] - Loss: 0.2948, Train Accuracy: 85.31%
# Batch [20/92] - Loss: 0.5671, Train Accuracy: 85.16%
# Batch [30/92] - Loss: 0.6648, Train Accuracy: 83.54%
# Batch [40/92] - Loss: 0.3824, Train Accuracy: 84.14%
# Batch [50/92] - Loss: 0.2125, Train Accuracy: 84.69%
# Batch [60/92] - Loss: 0.4103, Train Accuracy: 84.53%
# Batch [70/92] - Loss: 0.2997, Train Accuracy: 84.91%
# Batch [80/92] - Loss: 0.2333, Train Accuracy: 85.23%
# Batch [90/92] - Loss: 0.3110, Train Accuracy: 84.90%
# Epoch [6/10] - Validating...
# Epoch [6/10] - Train Loss: 0.3948, Train Accuracy: 84.98%, Val Loss: 0.5184, Val Accuracy: 82.67%, Time: 478.05 seconds
#
# Epoch [7/10] - Training...
# Batch [10/92] - Loss: 0.2874, Train Accuracy: 87.19%
# Batch [20/92] - Loss: 0.5275, Train Accuracy: 85.78%
# Batch [30/92] - Loss: 0.3167, Train Accuracy: 85.31%
# Batch [40/92] - Loss: 0.3245, Train Accuracy: 85.94%
# Batch [50/92] - Loss: 0.3726, Train Accuracy: 86.75%
# Batch [60/92] - Loss: 0.4048, Train Accuracy: 87.19%
# Batch [70/92] - Loss: 0.3267, Train Accuracy: 87.05%
# Batch [80/92] - Loss: 0.5984, Train Accuracy: 86.60%
# Batch [90/92] - Loss: 0.1529, Train Accuracy: 86.77%
# Epoch [7/10] - Validating...
# Best model saved with validation accuracy: 83.89%
# Epoch [7/10] - Train Loss: 0.3697, Train Accuracy: 86.66%, Val Loss: 0.4763, Val Accuracy: 83.89%, Time: 472.25 seconds
#
# Epoch [8/10] - Training...
# Batch [10/92] - Loss: 0.2038, Train Accuracy: 89.38%
# Batch [20/92] - Loss: 0.2334, Train Accuracy: 88.28%
# Batch [30/92] - Loss: 0.3842, Train Accuracy: 88.12%
# Batch [40/92] - Loss: 0.3426, Train Accuracy: 87.34%
# Batch [50/92] - Loss: 0.4321, Train Accuracy: 87.44%
# Batch [60/92] - Loss: 0.2347, Train Accuracy: 88.02%
# Batch [70/92] - Loss: 0.2122, Train Accuracy: 88.39%
# Batch [80/92] - Loss: 0.2362, Train Accuracy: 88.52%
# Batch [90/92] - Loss: 0.4345, Train Accuracy: 88.47%
# Epoch [8/10] - Validating...
# Best model saved with validation accuracy: 84.50%
# Epoch [8/10] - Train Loss: 0.3272, Train Accuracy: 88.46%, Val Loss: 0.5191, Val Accuracy: 84.50%, Time: 469.67 seconds
#
# Epoch [9/10] - Training...
# Batch [10/92] - Loss: 0.2601, Train Accuracy: 90.31%
# Batch [20/92] - Loss: 0.4676, Train Accuracy: 87.97%
# Batch [30/92] - Loss: 0.2215, Train Accuracy: 89.06%
# Batch [40/92] - Loss: 0.2650, Train Accuracy: 89.30%
# Batch [50/92] - Loss: 0.1938, Train Accuracy: 89.44%
# Batch [60/92] - Loss: 0.1834, Train Accuracy: 89.74%
# Batch [70/92] - Loss: 0.7481, Train Accuracy: 89.15%
# Batch [80/92] - Loss: 0.2651, Train Accuracy: 89.06%
# Batch [90/92] - Loss: 0.3757, Train Accuracy: 88.85%
# Epoch [9/10] - Validating...
# Epoch [9/10] - Train Loss: 0.2978, Train Accuracy: 88.84%, Val Loss: 0.5023, Val Accuracy: 82.98%, Time: 469.70 seconds
#
# Epoch [10/10] - Training...
# Batch [10/92] - Loss: 0.3164, Train Accuracy: 87.19%
# Batch [20/92] - Loss: 0.1883, Train Accuracy: 88.75%
# Batch [30/92] - Loss: 0.2914, Train Accuracy: 89.48%
# Batch [40/92] - Loss: 0.2560, Train Accuracy: 89.69%
# Batch [50/92] - Loss: 0.2191, Train Accuracy: 89.94%
# Batch [60/92] - Loss: 0.2395, Train Accuracy: 90.10%
# Batch [70/92] - Loss: 0.3090, Train Accuracy: 89.73%
# Batch [80/92] - Loss: 0.2285, Train Accuracy: 89.61%
# Batch [90/92] - Loss: 0.0895, Train Accuracy: 89.86%
# Epoch [10/10] - Validating...
# Epoch [10/10] - Train Loss: 0.2734, Train Accuracy: 89.93%, Val Loss: 0.5019, Val Accuracy: 83.89%, Time: 469.11 seconds
#
# Training complete. Best model saved at: best_model.pth

# %%
# Save the entire model
torch.save(model, 'model.pth')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import pretrainedmodels
from sklearn.metrics import precision_score, recall_score, f1_score, cohen_kappa_score

# Load the pretrained resnet50 model
model = pretrainedmodels.__dict__['resnet50'](num_classes=1000, pretrained='imagenet')
num_classes = 5

# Modify the final layer to match the number of classes
in_features = model.last_linear.in_features
model.last_linear = nn.Linear(in_features, num_classes)

# Load the fine-tuned model weights
model.load_state_dict(torch.load('best_model.pth'))
model.eval()


transform = transforms.Compose([
    transforms.Resize((299, 299)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the test dataset
test_dir = '/content/test'
test_dataset = datasets.ImageFolder(root=test_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Evaluation function
def evaluate(model, test_loader, criterion, device):
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item() * images.size(0)

            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = test_loss / total
    accuracy = correct / total

    return avg_loss, accuracy, all_preds, all_labels

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
criterion = nn.CrossEntropyLoss()
test_loss, test_accuracy, all_preds, all_labels = evaluate(model, test_loader, criterion, device)

print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy * 100:.2f}%")

# Calculate  evaluation metrics
precision = precision_score(all_labels, all_preds, average='weighted')
recall = recall_score(all_labels, all_preds, average='weighted')
f1 = f1_score(all_labels, all_preds, average='weighted')
kappa_score = cohen_kappa_score(all_labels, all_preds)
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Cohen's Kappa Score: {kappa_score:.4f}")
# Out:
# <ipython-input-38-8d5fd3d031a2>:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model.pth'))
# Test Loss: 0.4549, Test Accuracy: 83.62%
# Precision: 0.8352
# Recall: 0.8362
# F1 Score: 0.8315
# Cohen's Kappa Score: 0.7534

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
cm = confusion_matrix(all_labels, all_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
